# %%
import pandas as pd
import numpy as np

# %%
new = pd.read_csv('../data/raw/W2M-red_quasars.csv')
df = pd.read_csv('../data/train_qso.csv')

# %%
df
# Out:
#      Unnamed: 0   data           RA          DEC     G_mag     R_mag  \
# 0             0  SpIES  00:00:16.67  +00:05:22.5  23.35760  21.67810
# 1             1  SpIES  00:15:13.51  -00:32:59.1  22.56440  21.43420
# 2             2  SpIES  00:17:55.84  +00:50:47.5  23.13460  21.60430
# 3             3  SpIES  00:20:54.03  +00:13:31.0  23.20390  21.53910
# 4             4  SpIES  00:21:42.95  -00:06:07.2  22.91020  21.48390
# ..          ...    ...          ...          ...       ...       ...
# 156         156  FIRST   230.937775     8.142239  24.35768  23.59506
# 157         157  FIRST   231.474106    -0.764342  22.61378  21.60162
# 158         158  FIRST   232.366806     8.611883  23.78472  22.15773
# 159         159  FIRST   234.152176     6.422978  22.17300  20.99600
# 160         160  FIRST   234.350342    -1.147317  22.93707  21.72570
#
#          J_mag      K_mag redshift   U_mag  ...        zk       zw1       zw2  \
# ...

# %%
count_class = pd.DataFrame(new['class_cleaned'].value_counts()).reset_index()
count_class.rename(columns = {'index' : 'class_cleaned','class_cleaned':'occ'},inplace = True)

# %%
count_class
# Out:
#    class_cleaned  occ
# 0           none  155
# 1         no_obs  124
# 2              ?   77
# 3            QSO   67
# 4          NLAGN    4
# 5            AGN    2
# 6        QSO/AGN    2
# 7       weak-det    2
# 8      duplicate    2
# 9           NL??    1
# 10          star    1
# 11        NLAGN?    1
# 12  NLAGN?no_obs    1
# 13         Starb    1
