# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('../data/trian_qso_wo_petro_v2.csv')

# %%
df = data[['ug', 'ur', 'ui', 'uz', 'uj', 'uk', 'uw1', 'uw2', 'gr',
       'gi', 'gz', 'gk', 'gj', 'gw1', 'gw2', 'ri', 'rz', 'rj', 'rw1', 'rk',
       'rw2', 'iz', 'ij', 'ik', 'iw1', 'iw2', 'zj', 'zk', 'zw1', 'zw2', 'jw1',
       'jw2', 'jk', 'kw1', 'kw2', 'w1w2','class_bin']]

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df.iloc[:,11:14], 
               c= df['class_bin'],
               figsize=(15,11));

scatter_matrix(df.iloc[:,19:22], 
               c= df['class_bin'],
               figsize=(15,11));

# %%
from scipy.spatial import ConvexHull

plt.clf()
plt.figure(figsize = (10, 6))
names = ['non_quasar','quasar']
colors = ['b','r']
label = df['class_bin'].astype(np.int)
plt.title('g - J vs. J - K Color')
plt.xlabel(df.columns[12])
plt.ylabel(df.columns[32])

for i in range(len(names)):
    bucket = df[df['class_bin'] == i]
    bucket = bucket.iloc[:,[12,32]].values
    hull = ConvexHull(bucket)
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
    for j in hull.simplices:
        plt.plot(bucket[j,0], bucket[j,1], colors[i])

plt.legend()
plt.show()
# Out:
# /var/folders/dq/sc1tlll95vbbtbqb_dbg21km0000gn/T/ipykernel_96291/3319631221.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label = df['class_bin'].astype(np.int)

# %%
df = df[df['ug']!=975.915]

# %%
plt.clf()
plt.figure(figsize = (10, 6))
names = ['non_quasar','quasar']
colors = ['b','r']
label = df['class_bin'].astype(np.int)
plt.title('g-r vs. u-g Color')
plt.xlabel(df.columns[0])
plt.ylabel(df.columns[8])

for i in range(len(names)):
    bucket = df[df['class_bin'] == i]
    bucket = bucket.iloc[:,[0,8]].values
    hull = ConvexHull(bucket)
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
    for j in hull.simplices:
        plt.plot(bucket[j,0], bucket[j,1], colors[i])

plt.legend()
plt.show()
# Out:
# /var/folders/dq/sc1tlll95vbbtbqb_dbg21km0000gn/T/ipykernel_96291/3562692284.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label = df['class_bin'].astype(np.int)

# %% [markdown]
# ## Fix the columns

# %%
plt.clf()
plt.figure(figsize = (10, 6))
names = ['non_quasar','quasar']
colors = ['b','r']
label = df['class_bin'].astype(np.int)
plt.title('r-i vs g-r color')
plt.xlabel(df.columns[8])
plt.ylabel(df.columns[15])

for i in range(len(names)):
    bucket = df[df['class_bin'] == i]
    bucket = bucket.iloc[:,[8,15]].values
    hull = ConvexHull(bucket)
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
    for j in hull.simplices:
        plt.plot(bucket[j,0], bucket[j,1], colors[i])

plt.legend()
plt.savefig('../figures/faint/rig.png')
plt.show()
# Out:
# /var/folders/dq/sc1tlll95vbbtbqb_dbg21km0000gn/T/ipykernel_96291/2755530250.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label = df['class_bin'].astype(np.int)

# %%
plt.clf()
plt.figure(figsize = (10, 6))
names = ['non_quasar','quasar']
colors = ['b','r']
label = df['class_bin'].astype(np.int)
plt.title('i-z vs r-i color')
plt.xlabel(df.columns[15])
plt.ylabel(df.columns[21])

for i in range(len(names)):
    bucket = df[df['class_bin'] == i]
    bucket = bucket.iloc[:,[15,21]].values
    hull = ConvexHull(bucket)
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
    for j in hull.simplices:
        plt.plot(bucket[j,0], bucket[j,1], colors[i])

plt.legend()
plt.savefig('../figures/faint/izr.png')
plt.show()
# Out:
# /var/folders/dq/sc1tlll95vbbtbqb_dbg21km0000gn/T/ipykernel_96291/883021331.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label = df['class_bin'].astype(np.int)

# %%
plt.clf()
plt.figure(figsize = (10, 6))
names = ['non_quasar','quasar']
colors = ['b','r']
label = df['class_bin'].astype(np.int)
plt.title('r-k vs gok color')
plt.xlabel(df.columns[32])
plt.ylabel(df.columns[19])

for i in range(len(names)):
    bucket = df[df['class_bin'] == i]
    bucket = bucket.iloc[:,[32,12]].values
    hull = ConvexHull(bucket)
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
    for j in hull.simplices:
        plt.plot(bucket[j,0], bucket[j,1], colors[i])

plt.legend()
plt.show()
# Out:
# /var/folders/dq/sc1tlll95vbbtbqb_dbg21km0000gn/T/ipykernel_96291/3553324870.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label = df['class_bin'].astype(np.int)
